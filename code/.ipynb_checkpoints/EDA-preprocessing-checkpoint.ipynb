# %%
from skimage import feature
from skimage import color
from skimage import segmentation

from sklearn.cluster import KMeans
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import skimage
import skimage.io
import matplotlib.pylab as plt

# %matplotlib inline

# %%
import numpy as np
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
import pandas as pd
from skimage import data
from skimage import img_as_float
from skimage.morphology import reconstruction

def dialate(image):
    # Convert to float: Important for subtraction later which won't work with uint8
    #image = skimage.io.imread('./photodb3/lat37.758877_lng-122.414508ang045_61137.png', as_grey=True)
    image = gaussian_filter(image, 3)
    seed = np.copy(image)
    seed[1:-1, 1:-1] = image.min()
    mask = image
    dilated = reconstruction(seed, mask, method='dilation')
    return dilated

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
from os import listdir
from os.path import isfile, join
import itertools, shutil, os
import numpy as np
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
def createarray(filepath):
    p = skimage.io.imread(filepath)
    pgray = color.rgb2gray(p)
    X = pgray
    X = feature.canny(pgray,sigma=3)
#    X = dialate(pgray)
#     X = skimage.transform.resize(X,[100,100])
    return X.flatten()

# read images
features_array = []
dirpath = './photodb5/'
nn=0
rands = np.random.random_integers(0,10000,500)
domain = ['lat37.808214_lng-122.412463ang225_1173.png']#[listdir(dirpath)[i] for i in rands]
for i,f in enumerate(domain):
    if i%25 == 0:print(i,f)
    if isfile(join(dirpath,f)) & (len(f)>=31):
        print 1
        temp = createarray(dirpath +f)
        features_array.append(temp)
features_array = np.array(features_array)    
print('read_images done')
# Out:
# (0, 'lat37.808214_lng-122.412463ang225_1173.png')
# 1
# read_images done

# %%
X = features_array.reshape(400,300)
# X1 = skimage.transform.resize(X,[100,100])
fig, (ax2) = plt.subplots(nrows=1, ncols=1, figsize=(10, 10)) 
# ax1.imshow(features_array[3].reshape(100,100), cmap=plt.cm.jet)
# ax1.axis('off')
# ax1.set_title('noisy image', fontsize=20)

ax2.imshow(X, cmap=plt.cm.jet)
ax2.axis('off')
ax2.set_title('noisy image', fontsize=20)
X.shape
# Out:
# (400, 300)

# %%
features_array
import pandas as pd
df = pd.read_csv('latlong_distinct.csv')
df.shape
df.columns
df.plot(df['lng'].map(lambda x:float(x)), df['lat'].map(lambda x:float(x)), kind='scatter')
# Out:
# array([[False, False, False, ..., False, False, False]], dtype=bool)

# %%
import urllib
import urllib2
from skimage import io
def single_query(filename, lat, lng, fov, angle, pitch, label, ii, nsucs, ntries):
    link='https://maps.googleapis.com/maps/api/streetview?\
size=%dx%d&location=%.6f,%.6f&fov=%d&heading=%d&pitch=%d&key=AIzaSyCsHPCM6nVYgvItOGnmXq17FhvKtjOp44k'%(picsize[0],\
    picsize[1], lat, lng, fov, angle, pitch)
    print link
    urllib.urlretrieve(link, filename)
    a = io.imread(filename)
    pathname = info2name(lat, lng, angle, label)
    urllib.urlretrieve(link, filename)
    try:
        print '%d success!:%d %d Cum Success = %.3f' %(ii, nsucs, ntries, float(nsucs)/ntries)
    except ZeroDivisionError:
        print '%d success! Cum Success = %.3f' %(ii, 0)
    nsucs += 1
    ntries += 1
    return a,nsucs, ntries
def info2name(lat, lng, angle, label):
    return 'lat%.6f_lng%.6fang%03dlab%02d.png' %(lat,lng,angle,label)

# %%
meshsize = [5,5]
picsizes = [[200,200]]#,[400,200],[200,400],[600,200],[200,600],[400,400]]
angles = [45]
angles1 = [45, 90, 135, 180]
angles2 = [225, 180, 315, 360]
filename = 'testviews.png'
fovs = [140]#,90,70,50,30]
pitches = [0,70,90]
for ang in angles:
    fig, ax = plt.subplots(2,(len(picsizes)+1)/2,figsize=[20,20])
    for i,picsize in enumerate(picsizes):
#         fig, ax = plt.subplots(2,(len(fovs)+1)/2,figsize=[20,20])
        for j, fov in enumerate(fovs):
            for pitch in pitches:
                fig, ax = plt.subplots(2,(len(fovs)+1)/2,figsize=[20,20])
                a, nsucs_new, ntries = single_query(filename, df.lat[0],df.lng[0],fov,ang,pitch, 1, 1 , 1, 1)
                ax.flatten()[i].imshow(a)
                
    #             ax.show()
# Out:
# https://maps.googleapis.com/maps/api/streetview?size=200x200&location=37.792777,-122.419416&fov=140&heading=45&pitch=0&key=AIzaSyCsHPCM6nVYgvItOGnmXq17FhvKtjOp44k
# 1 success!:1 1 Cum Success = 1.000
# https://maps.googleapis.com/maps/api/streetview?size=200x200&location=37.792777,-122.419416&fov=140&heading=45&pitch=70&key=AIzaSyCsHPCM6nVYgvItOGnmXq17FhvKtjOp44k
# 1 success!:1 1 Cum Success = 1.000
# https://maps.googleapis.com/maps/api/streetview?size=200x200&location=37.792777,-122.419416&fov=140&heading=45&pitch=90&key=AIzaSyCsHPCM6nVYgvItOGnmXq17FhvKtjOp44k
# 1 success!:1 1 Cum Success = 1.000

# %%
ls
# Out:
# EDA-Copy1.ipynb                        latlong.csv                            photodb31/
# EDA-pca.ipynb                          latlong_distinct.csv                   photodb41/
# EDA-preprocessing.ipynb                latlong_extract-Copy1.ipynb            photodb41.tar
# List_of_Streets_and_Intersections.csv  latlong_extract-Copy2.ipynb            photodb5/
# Registered_Business_Map.csv            latlongneighborhood.csv                photodb6/
# TOAraw2latlng.py                       photodb10/                             photodb7/
# Xyread.py                              photodb11/                             photodb8/
# cnet2_reg.py                           photodb12/                             photodb9/
# collection.py                          photodb13/                             photodb_NE/
# collection.pyc                         photodb13-1/                           photodb_NE.tar
# ...

# %%
df_sucssess1=pd.read_csv('photodb14/imagedata2.csv')
df_sucssess2=pd.read_csv('photodb14/imagedata2.csv')

# %%
dff1 = df_sucssess1.dropna()
dff2 = df_sucssess2.dropna()

# %%
dff1.plot('lat','lng',kind='scatter',s=5,figsize=[20,20])
dff2.plot('lat','lng',kind='scatter',s=5,figsize=[20,20])

# %%
dff1.shape
# Out:
# (9591, 6)

# %%
dff2.shape
# Out:
# (9591, 6)

# %%
pwd
# Out:
# u'/Users/alizaf/Google Drive/GIT/project/data'

# %%
dfb = pd.read_csv("Registered_Business_Map.csv")
dfs = pd.read_csv("List_of_Streets_and_Intersections.csv")
dfb.groupby('Street_Address').count().sort(ascending=0)
# dfs.groupby('streetname').count()
dfb['Street_Address'].map(lambda x: str(x).split())

BL = dfb['Business_Location'].map(lambda x: str(x).split())
avenues = [BL[i] for i in range(len(BL)) if 'AVE' in BL[i]]
avenues = [BL[i] for i in range(len(BL)) if 'AVE' in BL[i]]
dfb['BL1'] = [BL[i][1] if len(BL[i])>1 else 0 for i in range(len(BL)) ]
dfb['BL2'] = [BL[i][2] if len(BL[i])>1 else 0 for i in range(len(BL)) ]
top50 = dfb.groupby('BL1').count().sort('Location_ID', ascending=False)[:70]
top50.index

# %%
dfb_filt = dfb
dfb_filt['BL1'] = dfb['BL1'].apply(lambda x: x if x in top50.index else '')

# %%
dfb_filt = dfb_filt[dfb_filt['BL1'] != '']

# %%
dfb_filt.to_csv('Main_st_Buisinesses.csv')

# %%
dfbg = dfb.groupby('BL1')

# %%
# def cleaner():
df = pd.DataFrame(np.zeros([1,3]),columns = ['stname','lat', 'lng'])
for stname in top50.index:
    dfraw = dfbg.get_group(stname)
    df_latlng = dfraw['Business_Location'].map(lambda x: str(x).split()[-2:])
    df_lat = df_latlng.map(lambda x: x[0][1:-1])
    df_lng = df_latlng.map(lambda x: x[-1][0:-1])
    df_stname = df_latlng.map(lambda x: stname)
    df_latlng = pd.concat([df_stname,df_lat,df_lng],1)
    df_latlng.columns = ['stname','lat', 'lng']
    df = df.append(df_latlng.convert_objects(convert_numeric=True))
df = df.drop(0).reset_index()

# %%
for stname in top50.index:
g = getview(
# Out:
#         index    stname        lat         lng
# 0          83    MARKET  37.767224 -122.429458
# 1         168    MARKET  37.786254 -122.405259
# 2         186    MARKET  37.789264 -122.401418
# 3         197    MARKET  37.774584 -122.420077
# 4         198    MARKET  37.774584 -122.420077
# 5         202    MARKET  37.764629 -122.432419
# 6         238    MARKET  37.790697 -122.399562
# 7         274    MARKET  37.793585 -122.395889
# 8         295    MARKET  37.786254 -122.405259
# 9         296    MARKET  37.786254 -122.405259
# 10        346    MARKET  37.792037 -122.397851
# 11        379    MARKET  37.789264 -122.401418
# 12        403    MARKET  37.767224 -122.429458
# 13        447    MARKET  37.767289 -122.429381
# 14        457    MARKET  37.773620 -122.421177
# 15        508    MARKET  37.777014 -122.416988
# 16        674    MARKET  37.772708 -122.422371
# 17        675    MARKET  37.772708 -122.422371
# 18        687    MARKET  37.789264 -122.401418
# ...

# %%
cd photodb_MainST_NE/
# Out:
# /Users/alizaf/Google Drive/GIT/project/data/photodb_MainST_NE

# %%
size=[]
name = []
for f in os.listdir('./'):
    size.append(os.stat(f).st_size)
    name.append(f)

# %%
df = pd.DataFrame({'name':name,'size':size})

# %%
df2 = df.drop_duplicates('size').copy()

# %%
df2['lat'] = df2['name'].map(lambda x: x[3:12])
df2['lat'] = df2['lat'].convert_objects(convert_numeric=True)
df2['lng'] = df2['name'].map(lambda x: x[16:27])
df2['lng'] = df2['lng'].convert_objects(convert_numeric=True)

# %%
df2.plot('lng','lat',kind='scatter',s=0.4,figsize=[25,20])

# %%
import googlemaps as gmp
